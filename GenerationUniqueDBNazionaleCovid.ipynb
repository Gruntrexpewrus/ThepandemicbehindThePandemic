# %%
import csv
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\leona\Desktop\Covid\dpc-covid19-ita-andamento-nazionale.csv")

# %%
df
# Out:
#                     data stato  ricoverati_con_sintomi  terapia_intensiva  \
# 0    2020-02-24T18:00:00   ITA                     101                 26
# 1    2020-02-25T18:00:00   ITA                     114                 35
# 2    2020-02-26T18:00:00   ITA                     128                 36
# 3    2020-02-27T18:00:00   ITA                     248                 56
# 4    2020-02-28T18:00:00   ITA                     345                 64
# ..                   ...   ...                     ...                ...
# 146  2020-07-19T17:00:00   ITA                     743                 49
# 147  2020-07-20T17:00:00   ITA                     745                 47
# 148  2020-07-21T17:00:00   ITA                     732                 49
# 149  2020-07-22T17:00:00   ITA                     724                 48
# 150  2020-07-23T17:00:00   ITA                     713                 49
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# ...

# %%
df.tail(10)
# Out:
#                     data stato  ricoverati_con_sintomi  terapia_intensiva  \
# 141  2020-07-14T17:00:00   ITA                     777                 60
# 142  2020-07-15T17:00:00   ITA                     797                 57
# 143  2020-07-16T17:00:00   ITA                     750                 53
# 144  2020-07-17T17:00:00   ITA                     771                 50
# 145  2020-07-18T17:00:00   ITA                     757                 50
# 146  2020-07-19T17:00:00   ITA                     743                 49
# 147  2020-07-20T17:00:00   ITA                     745                 47
# 148  2020-07-21T17:00:00   ITA                     732                 49
# 149  2020-07-22T17:00:00   ITA                     724                 48
# 150  2020-07-23T17:00:00   ITA                     713                 49
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# 141                   837                   12082            12919
# ...

# %%
def f(df):
    df.drop([ 'stato'], axis = 1, inplace = True)
    df.fillna(0, inplace = True)
    df['data'] = df['data'].str.slice(0,10)
    tosubtract = ['tamponi', 'casi_testati', 'deceduti' ]
    h = 0
    count_row = df.shape[0] 
    df['nuovi_tamponi'] = df['tamponi'][0]
    df['nuovi_casi_testati'] = df['casi_testati'][0]
    df['nuovi_deceduti'] =  df['deceduti'][0]
    for i in range(1, count_row):
            for j in tosubtract:
               # print(temp[j][i]-temp[j][i-1])
                df.at[i,'nuovi_'+j] = df[j][i]-df[j][i-1]
    df.to_csv('DataCovidNEW/NATIONALDATACOVIDDAYBYDAY.csv', index = False)
    return df

# %%
f(df)
# Out:
#            data  ricoverati_con_sintomi  terapia_intensiva  \
# 0    2020-02-24                     101                 26
# 1    2020-02-25                     114                 35
# 2    2020-02-26                     128                 36
# 3    2020-02-27                     248                 56
# 4    2020-02-28                     345                 64
# ..          ...                     ...                ...
# 146  2020-07-19                     743                 49
# 147  2020-07-20                     745                 47
# 148  2020-07-21                     732                 49
# 149  2020-07-22                     724                 48
# 150  2020-07-23                     713                 49
#
#      totale_ospedalizzati  isolamento_domiciliare  totale_positivi  \
# 0                     127                      94              221
# 1                     150                     162              311
# ...

# %%
import matplotlib.pyplot as plt
df['nuovi_tamponi'].plot()

# %%
df['deceduti'].plot()

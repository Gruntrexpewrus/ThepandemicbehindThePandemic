# %%
# Sentiment analysis for articles

# %%
from sentita import calculate_polarity
import numpy as np
from tqdm import tqdm
import pandas as pd

# %%
dataset_root = 'data/'
nonpreprocessed_articles = pd.read_csv(dataset_root + 'articles.csv', sep = ';', index_col = [0])
nonpreprocessed_articles
# Out:
#                                                    title  \
# 0      D’Alberto alla riunione delle ANCI regionali c...
# 1      Coronavirus, le novità introdotte dal DPCM 10 ...
# 2      Coronavirus, nuove misure per vendita generi a...
# 3      Regione, ecco la guida per la formazione a dis...
# 4      Ministro Amendola e Oddati all’iniziativa Pd A...
# ...                                                  ...
# 24579  Copie pirata di giornali su Telegram, salgono ...
# 24580  Inchiesta sulla sanità umbra, chiuse le indagi...
# 24581  Coronavirus in Italia, 3691 denunciati nel pri...
# 24582  Coronavirus, Medicina, la denuncia di Azione: ...
# 24583  La protesta di parrucchieri ed estetisti: "Se ...
#
#                                                  content        date  \
# 0      TERAMO – Il Presidente Gianguido D’Alberto ha ...  2020-04-15
# 1      Sul sito del Ministero dell’Interno è stata pu...  2020-04-15
# 2      PESCARA – Oggi, mercoledì 15 aprile, il Presid...  2020-04-15
# 3      PESCARA – Una vera e propria guida operativa i...  2020-04-15
# 4      REGIONE – “Le scelte del Pd. Per l’Italia e pe...  2020-04-15
# ...                                                  ...         ...
# 24579  È salito a 114 il numero dei canali Telegram s...  2020-05-04
# 24580  La chiusura dell'indagine sulle assunzioni in ...  2020-05-04
# 24581  ROMA - Chi si aspettava un boom di sanzioni ne...  2020-05-05
# 24582  Ventiduemila medici sono pronti a entrare in s...  2020-05-06
# 24583  ROMA - Il Censis in più occasioni lo ha defini...  2020-05-07
#
#               author   region    zone
# 0        Abruzzonews  Abruzzo  Centre
# 1        Abruzzonews  Abruzzo  Centre
# 2        Abruzzonews  Abruzzo  Centre
# 3        Abruzzonews  Abruzzo  Centre
# 4        Abruzzonews  Abruzzo  Centre
# ...              ...      ...     ...
# 24579  La Repubblica    Lazio  Centre
# 24580  La Repubblica    Lazio  Centre
# 24581  La Repubblica    Lazio  Centre
# 24582  La Repubblica    Lazio  Centre
# 24583  La Repubblica    Lazio  Centre
#
# [24584 rows x 6 columns]

# %%
cols = ['article_id', 'positive_avg', 'negative_avg', 'positive_max', 'negative_min', 'polarities_content_splits']
polarity_dataframe = pd.DataFrame()

articles_index = nonpreprocessed_articles.index
for i in tqdm(articles_index):
    _, test_pol = calculate_polarity(nonpreprocessed_articles.loc[i, 'content'].split('.'))
    
    positive_polarities = [x[0] for x in test_pol]
    negative_polarities = [x[1] for x in test_pol]
    
    positive_avg = np.mean(positive_polarities)
    negative_avg = np.mean(negative_polarities)
    
    positive_max = max(positive_polarities)
    negative_min = min(negative_polarities)

    
    score = [i, positive_avg, negative_avg, positive_max, negative_min, test_pol]  # (index, positive average polarity, negative average polarity, max pos pol , min neg pol)
    
    polarity_dataframe = polarity_dataframe.append(pd.DataFrame([score], columns = cols))
    
    #if len(polarity_dataframe.index) % 10 == 0:
        #polarity_dataframe.to_csv(dataset_root + 'article_polarities.csv', sep = ';', na_rep = 'nan')
# Out:
# 100%|██████████| 24584/24584 [3:59:15<00:00,  1.71it/s]

# %%
polarity_dataframe = polarity_dataframe.reset_index(drop = True)
#polarity_dataframe.to_csv(dataset_root + 'article_polarities.csv', sep = ';', na_rep = 'nan')
polarity_dataframe
# Out:
#        article_id  positive_avg  negative_avg  positive_max  negative_min  \
# 0               0      0.046155      0.044203      0.584534      0.000009
# 1               1      0.133937      0.076886      0.584534      0.000006
# 2               2      0.171993      0.065472      0.630472      0.000009
# 3               3      0.065227      0.026881      0.584534      0.000010
# 4               4      0.196379      0.138541      0.615877      0.000013
# ...           ...           ...           ...           ...           ...
# 24579       24579      0.001350      0.004847      0.006938      0.000012
# 24580       24580      0.000034      0.000049      0.000168      0.000007
# 24581       24581      0.151941      0.170270      0.617739      0.000081
# 24582       24582      0.022013      0.066938      0.096909      0.000012
# 24583       24583      0.030229      0.139485      0.189106      0.000025
#
#                                polarities_content_splits
# 0      [[0.00092852116, 0.0005393326], [0.00010349075...
# 1      [[8.377696e-06, 1.613107e-05], [4.9787727e-06,...
# 2      [[2.8751943e-05, 1.2847595e-05], [8.00114e-06,...
# 3      [[5.6668465e-05, 4.3567474e-05], [8.147673e-06...
# 4      [[0.006206006, 0.0057546496], [9.530106e-05, 7...
# ...                                                  ...
# 24579  [[5.957129e-06, 1.2265669e-05], [9.896326e-06,...
# 24580  [[0.0001681745, 0.00012552738], [5.7433404e-06...
# 24581  [[1.6639458e-05, 8.127809e-05], [0.6177395, 0....
# 24582  [[0.00041374564, 0.0017509758], [0.0046955347,...
# 24583  [[0.00018882751, 6.91584e-05], [7.3880576e-05,...
#
# [24584 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
ax = sns.heatmap(polarity_dataframe.iloc[:,1:].corr().values,
                 annot = True,
                 xticklabels=cols[1:5],
                 yticklabels=cols[1:5])

plt.xticks(rotation = 90)
plt.show()

# %%
average_pos_value = polarity_dataframe.positive_avg.mean()
average_neg_value = polarity_dataframe.negative_avg.mean()

print('Average positive value is', average_pos_value)
print('Average negative value is', average_neg_value)
# Out:
# Average positive value is 0.13483428824480007
# Average negative value is 0.10872665876878458

# %%
iterations = []
number_pos_articles = []
number_neg_articles = []

a = 0.01
interval = [(x/(a + x)) for x in np.linspace(0, 1, 5000)]

for index, num in zip(range(len(interval)), interval):
    iterations.append(num)
    
    number_pos_articles.append(len(polarity_dataframe[polarity_dataframe.positive_avg > num].index))
    number_neg_articles.append(len(polarity_dataframe[polarity_dataframe.negative_avg > num].index))
    

plt.figure(figsize = (5, 10))
    
sns.lineplot(iterations, number_pos_articles)
plt.title('Number of positive polarity articles')
plt.xlabel('Polarity threshold')
plt.ylabel('Number of articles')
plt.show()

plt.figure(figsize = (5, 10))

sns.lineplot(iterations, number_neg_articles, color = 'C1')
plt.title('Number of negative polarity articles')
plt.xlabel('Polarity threshold')
plt.ylabel('Number of articles')
plt.show()

# %%
articles = pd.read_csv(dataset_root + 'articles.csv', sep = ';', index_col = [0])

# %%
clearly_negative = polarity_dataframe[polarity_dataframe.negative_avg > 0.5]
clearly_neg_index = clearly_negative['article_id'].values[0]

for i in clearly_negative.article_id.values:
    print(articles.loc[i, 'title'], end = '\n\n')
# Out:
# Castelletto, altro furto in casa di notte. Ladri fuggiti indisturbati
#
# Nottata di lavoro per i vigili del fuoco ad Albenga
#
# Giustizia o giustezza? Le domande dello scolaro Esposito Ingenuo
#
# L’emergenza stultus virus. Gli idioti sono contagiosi
#
# Vandali in azione a Trieste
#
# Getta un mozzicone non spento, scoppia l'incendio
#
# Coronavirus, fuma la sigaretta elettronica con la mascherina abbassata, 400euro di multa: “Mi hanno fatto fare una figuraccia, temevo mi licenziassero”
#
# Incendio in A22, in fiamme il rimorchio di un camion
#
# Coronavirus Napoli, ecco quali sono i servizi sempre aperti: igiene, polizia e assistenza
#
# Invalido fa pipì contro un muro, denuncia e maximulta da 3.333 euro: «Sono disperato»
#
# Maria Antonietta Rositani: «Bruciata dal mio ex e tradita dallo Stato: ho paura che esca dal...
#
# La denuncia: «Ho febbre e tosse. Perché non mi fanno il tampone?»
#
# Coronavirus Covid, inferno in Ecuador: i cadaveri bruciati in strada o gettati nei cassonetti
#
# Pericoloso fare 2 volte la spesa, si chiuda tutto: denuncia di macellaia a Pastena
#
# Furto al Loreto Mare, rubati i portafogli di medici e infermieri negli spogliatoi
#
# Lunghe code per i mezzi pubblici a Roma: "Il distanziamento non esiste"
#
# Folla alla Vucciria, Musumeci: "Se si continua così, torneremo indietro"
#
# Farmacista compra mascherine online ma riceve stoviglie e piatti sporchi: "Pagate 10 mila euro"
#
# Coronavirus, l'organizzatore della grigliata di Palermo: "Eravamo convinti di non fare nulla di...
#
# Fase 2, Lamorgese: italiani sono stati responsabili, siamo soddisfatti | Conte: "Se proseguiamo...
#
# "Se apriamo falliamo!", la protesta dei ristoratori a Milano
#
# Genova, principio di incendio in un deposito di Fincantieri. Nessun ferito
#
# Falsi concorsi e falsi buoni spesa, non cliccare sui link che si ricevono
#
# Incendio auto in via Cortonese, torna la paura a Fontivegge
#
# Controlli Covid, multe da 522 euro per chi prende il caffè nelle aree di servizio della tangenziale
